# %%
<print("hellow world")>
# Out:
#   Cell In[2], line 1
#     <print("hellow world")>
#     ^
# SyntaxError: invalid syntax

# %%
import numpy as np
print(np.random.random())
# Out:
# 0.4321345322986966

# %%
print(random.randrange(5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(random.randrange(5))
#
# NameError: name 'random' is not defined

# %%
class restaurant:
    def __init__(self, name, cuisine, location):
        self.name = name
        self.cuisine = cuisine
        self.location = location

    def describe(self):
        return(f"{self.name} is a {self.cuisine} restaurant based in {self.location}")

Res_1 = restaurant("Django","steak", "Didcot")


Res_1.describe()
# Out:
# 'Django is a steak restaurant based in Didcot'
