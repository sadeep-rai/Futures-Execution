# %%
from collections import deque

# Start with a queue of tasks
tasks = deque(['task1', 'task2', 'task3'])

# Add a new task to the end (fast)
tasks.append('task4')

# Handle the oldest task (fast)
oldest = tasks.popleft()

print(f"Handled: {oldest}")
print(f"Remaining queue: {tasks}")
# Out:
# Handled: task1
# Remaining queue: deque(['task2', 'task3', 'task4'])

# %%
print(oldest)
# Out:
# task1

# %%
class MyEnv:
    def __init__(self):
        self.current_step = 0  # instance variable

    def next(self):
        self.current_step += 1

# Create two different environment instances
env1 = MyEnv()
env2 = MyEnv()

env1.next()
env1.next()
env1.next()
env1.next()
env2.next()

print(env1.current_step)  # 2
print(env2.current_step)  # 0
# Out:
# 4
# 1

# %%
class car(self):
    def __init__(self, model, brand):
        self.model = model
        self.brand = brand
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7ecca34167a7> in <module>
# ----> 1 class car(self):
#       2     def __init__(self, model, brand):
#       3         self.model = model
#       4         self.brand = brand
#       5
#
# NameError: name 'self' is not defined

# %%
print("hello world")
# Out:
# hello world
